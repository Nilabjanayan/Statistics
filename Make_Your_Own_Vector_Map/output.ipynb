# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import mpldatacursor
# %matplotlib inline

# %%
output = pd.read_csv("output.csv")
output.head(4)
# Out:
#                 locations    x_global   y_global
# 0  akhandananda bhawan NE  693.873948  2149.9935
# 1  akhandananda bhawan NW  527.480448  2110.0980
# 2  akhandananda bhawan SE  690.452448  2212.6735
# 3  akhandananda bhawan SW  497.848948  2191.0175

# %%
img = cv2.imread('stitched_images/stitched.png')

# %%
plt.figure(figsize = (20,20))
plt.imshow(img)
plt.plot(np.array(output["x_global"])+150,output["y_global"],'r*')
plt.savefig("stitched_images/output.png")

# %% [markdown]
# <h4>Check the Outputs</h4>

# %%
# %matplotlib notebook
plt.figure(figsize = (10,10))
plt.imshow(img)
plt.plot(np.array(output["x_global"])+150,output["y_global"],'r*')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="719.9999843944206">
